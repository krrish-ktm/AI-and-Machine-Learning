# %%
import zipfile

zip_path = "/content/drive/MyDrive/AI and Machine Learning/Copy of devnagari digit.zip"
extract_path = "/content/drive/MyDrive/AI and Machine Learning"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import os
import numpy as np
from PIL import Image

# %% [markdown]
# Load & Preprocess Data (PIL method)

# %%
import os
import numpy as np
from PIL import Image
from tensorflow.keras.utils import to_categorical

# Dataset paths
train_dir = "/content/drive/MyDrive/AI and Machine Learning/DevanagariHandwrittenDigitDataset/Train"
test_dir = "/content/drive/MyDrive/AI and Machine Learning/DevanagariHandwrittenDigitDataset/Test"

img_size = 28

def load_images(folder):
    images = []
    labels = []

    class_names = sorted(os.listdir(folder))
    class_map = {name: i for i, name in enumerate(class_names)}

    for class_name in class_names:
        class_path = os.path.join(folder, class_name)
        label = class_map[class_name]

        for file in os.listdir(class_path):
            img_path = os.path.join(class_path, file)

            img = Image.open(img_path).convert("L")
            img = img.resize((img_size, img_size))
            img = np.array(img) / 255.0

            images.append(img)
            labels.append(label)

    return np.array(images), np.array(labels)

# Load data
x_train, y_train = load_images(train_dir)
x_test, y_test = load_images(test_dir)

# Reshape
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# One-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print(x_train.shape, y_train.shape)
# Out:
# (17000, 28, 28, 1) (17000, 10)

# %% [markdown]
# Build FCN Model

# %%
from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28, 1)),

    layers.Dense(64, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(256, activation='sigmoid'),

    layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
history = model.fit(
    x_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3988 - loss: 1.7538 - val_accuracy: 0.0000e+00 - val_loss: 6.7043
# Epoch 2/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8351 - loss: 0.5837 - val_accuracy: 0.0000e+00 - val_loss: 8.0641
# Epoch 3/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9210 - loss: 0.2844 - val_accuracy: 0.0000e+00 - val_loss: 8.6954
# Epoch 4/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9461 - loss: 0.1932 - val_accuracy: 0.0000e+00 - val_loss: 9.1295
# Epoch 5/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9577 - loss: 0.1470 - val_accuracy: 0.0000e+00 - val_loss: 9.2941
# Epoch 6/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9661 - loss: 0.1175 - val_accuracy: 0.0000e+00 - val_loss: 9.5308
# Epoch 7/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9730 - loss: 0.0943 - val_accuracy: 0.0000e+00 - val_loss: 9.8325
# Epoch 8/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9781 - loss: 0.0775 - val_accuracy: 0.0000e+00 - val_loss: 10.0261
# Epoch 9/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9831 - loss: 0.0640 - val_accuracy: 0.0000e+00 - val_loss: 10.2207
# Epoch 10/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9868 - loss: 0.0533 - val_accuracy: 0.0000e+00 - val_loss: 10.3771
# Epoch 11/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9885 - loss: 0.0450 - val_accuracy: 0.0000e+00 - val_loss: 10.6256
# Epoch 12/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9915 - loss: 0.0369 - val_accuracy: 0.0000e+00 - val_loss: 10.5669
# Epoch 13/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9940 - loss: 0.0299 - val_accuracy: 0.0000e+00 - val_loss: 10.7809
# Epoch 14/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9953 - loss: 0.0250 - val_accuracy: 0.0000e+00 - val_loss: 10.9304
# Epoch 15/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9966 - loss: 0.0203 - val_accuracy: 0.0000e+00 - val_loss: 11.0124
# Epoch 16/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9976 - loss: 0.0168 - val_accuracy: 0.0000e+00 - val_loss: 11.1202
# Epoch 17/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9979 - loss: 0.0141 - val_accuracy: 0.0000e+00 - val_loss: 11.4616
# Epoch 18/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0114 - val_accuracy: 0.0000e+00 - val_loss: 11.5814
# Epoch 19/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9989 - loss: 0.0096 - val_accuracy: 0.0000e+00 - val_loss: 11.7182
# Epoch 20/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9991 - loss: 0.0079 - val_accuracy: 0.0000e+00 - val_loss: 11.6896

# %% [markdown]
# Evaluate Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7833 - loss: 2.3849
# Test Accuracy: 0.7833333611488342

# %% [markdown]
# Save & Load Model

# %%
# Save model (NEW FORMAT)
model.save("devnagari_model.keras")

# Load model
from tensorflow.keras.models import load_model
loaded_model = load_model("devnagari_model.keras")

# Evaluate to initialize metrics
loaded_model.evaluate(x_test, y_test)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7833 - loss: 2.3849
# [2.384884834289551, 0.7833333611488342]

# %% [markdown]
# Predictions

# %%
import numpy as np

predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

print("Predicted:", predicted_labels[0])
print("Actual:", np.argmax(y_test[0]))
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Predicted: 0
# Actual: 0

# %% [markdown]
# Plot Accuracy & Loss

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")
plt.legend(["Train", "Validation"])
plt.show()
