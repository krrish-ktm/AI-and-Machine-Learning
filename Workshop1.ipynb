# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image

# %%
image_colored = Image.open("/content/drive/MyDrive/AI and Machine Learning/image.jpeg")

# %%
print("Format:",image_colored.format)
print("Mode:",image_colored.mode)
print("Size:",image_colored.size)
# Out:
# Format: JPEG
# Mode: RGB
# Size: (736, 920)

# %%
image_colored= image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %%
image_grayed= image_colored.convert('L')
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=736x920>

# %%
print(image_grayed.size)
print(image_grayed.mode)
print(image_grayed.format)
# Out:
# (736, 920)
# L
# None

# %%
width,height = image_grayed.size
channels=len(image_grayed.getbands())

print(f"Image shape (gray): ({height} , {width}, {channels})")

image_size_grayed = width*height*1
print(f"Image size(gray) : {image_size_grayed}")
# Out:
# Image shape (gray): (920 , 736, 1)
# Image size(gray) : 677120

# %%
width,height = image_colored.size
channels=len(image_colored.getbands())

print(f"Image shape (RGB): ({height} , {width}, {channels})")

image_size_colored = width*height*channels
print(f"Image size(RGB) : {image_size_colored}")
# Out:
# Image shape (RGB): (920 , 736, 3)
# Image size(RGB) : 2031360

# %%
import numpy as np
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (920, 736, 3)

# %%
image_array_grayed = np.array(image_grayed)
image_array_grayed.shape
# Out:
# (920, 736)

# %% [markdown]
# Accesing individual channels

# %%
red_channel=image_array_colored[:,:,0]
print(red_channel)
display(red_channel)
# Out:
# [[143 143 143 ... 222 220 218]
#  [143 143 144 ... 229 227 225]
#  [143 143 144 ... 226 225 225]
#  ...
#  [ 69  69  69 ... 112 120 128]
#  [ 69  69  69 ... 114 120 132]
#  [ 68  68  69 ... 115 121 135]]
# array([[143, 143, 143, ..., 222, 220, 218],
#        [143, 143, 144, ..., 229, 227, 225],
#        [143, 143, 144, ..., 226, 225, 225],
#        ...,
#        [ 69,  69,  69, ..., 112, 120, 128],
#        [ 69,  69,  69, ..., 114, 120, 132],
#        [ 68,  68,  69, ..., 115, 121, 135]], dtype=uint8)

# %%
red_channel=image_array_colored.copy()
red_channel[:,:,1]=0
red_channel[:,:,2]=0
print(red_channel)
display(red_channel)
# Out:
# [[[143   0   0]
#   [143   0   0]
#   [143   0   0]
#   ...
#   [222   0   0]
#   [220   0   0]
#   [218   0   0]]
#
#  [[143   0   0]
#   [143   0   0]
#   [144   0   0]
#   ...
#   [229   0   0]
#   [227   0   0]
#   [225   0   0]]
#
#  [[143   0   0]
#   [143   0   0]
#   [144   0   0]
#   ...
#   [226   0   0]
#   [225   0   0]
#   [225   0   0]]
#
#  ...
#
#  [[ 69   0   0]
#   [ 69   0   0]
#   [ 69   0   0]
#   ...
#   [112   0   0]
#   [120   0   0]
#   [128   0   0]]
#
#  [[ 69   0   0]
#   [ 69   0   0]
#   [ 69   0   0]
#   ...
#   [114   0   0]
#   [120   0   0]
#   [132   0   0]]
#
#  [[ 68   0   0]
#   [ 68   0   0]
#   [ 69   0   0]
#   ...
#   [115   0   0]
#   [121   0   0]
#   [135   0   0]]]
# array([[[143,   0,   0],
#         [143,   0,   0],
#         [143,   0,   0],
#         ...,
#         [222,   0,   0],
#         [220,   0,   0],
#         [218,   0,   0]],
#
#        [[143,   0,   0],
#         [143,   0,   0],
#         [144,   0,   0],
#         ...,
#         [229,   0,   0],
#         [227,   0,   0],
#         [225,   0,   0]],
#
#        [[143,   0,   0],
#         [143,   0,   0],
#         [144,   0,   0],
#         ...,
#         [226,   0,   0],
#         [225,   0,   0],
#         [225,   0,   0]],
#
#        ...,
#
#        [[ 69,   0,   0],
#         [ 69,   0,   0],
#         [ 69,   0,   0],
#         ...,
#         [112,   0,   0],
#         [120,   0,   0],
#         [128,   0,   0]],
#
#        [[ 69,   0,   0],
#         [ 69,   0,   0],
#         [ 69,   0,   0],
#         ...,
#         [114,   0,   0],
#         [120,   0,   0],
#         [132,   0,   0]],
#
#        [[ 68,   0,   0],
#         [ 68,   0,   0],
#         [ 69,   0,   0],
#         ...,
#         [115,   0,   0],
#         [121,   0,   0],
#         [135,   0,   0]]], dtype=uint8)

# %%
green_channel=image_array_colored.copy()
green_channel[:,:,0]=0
green_channel[:,:,2]=0
print(green_channel)
display(green_channel)
# Out:
# [[[  0 128   0]
#   [  0 128   0]
#   [  0 128   0]
#   ...
#   [  0 195   0]
#   [  0 194   0]
#   [  0 194   0]]
#
#  [[  0 128   0]
#   [  0 128   0]
#   [  0 129   0]
#   ...
#   [  0 201   0]
#   [  0 201   0]
#   [  0 201   0]]
#
#  [[  0 128   0]
#   [  0 128   0]
#   [  0 129   0]
#   ...
#   [  0 200   0]
#   [  0 200   0]
#   [  0 203   0]]
#
#  ...
#
#  [[  0  52   0]
#   [  0  52   0]
#   [  0  52   0]
#   ...
#   [  0  89   0]
#   [  0  98   0]
#   [  0 106   0]]
#
#  [[  0  52   0]
#   [  0  52   0]
#   [  0  52   0]
#   ...
#   [  0  91   0]
#   [  0  98   0]
#   [  0 110   0]]
#
#  [[  0  51   0]
#   [  0  51   0]
#   [  0  52   0]
#   ...
#   [  0  92   0]
#   [  0  99   0]
#   [  0 113   0]]]
# array([[[  0, 128,   0],
#         [  0, 128,   0],
#         [  0, 128,   0],
#         ...,
#         [  0, 195,   0],
#         [  0, 194,   0],
#         [  0, 194,   0]],
#
#        [[  0, 128,   0],
#         [  0, 128,   0],
#         [  0, 129,   0],
#         ...,
#         [  0, 201,   0],
#         [  0, 201,   0],
#         [  0, 201,   0]],
#
#        [[  0, 128,   0],
#         [  0, 128,   0],
#         [  0, 129,   0],
#         ...,
#         [  0, 200,   0],
#         [  0, 200,   0],
#         [  0, 203,   0]],
#
#        ...,
#
#        [[  0,  52,   0],
#         [  0,  52,   0],
#         [  0,  52,   0],
#         ...,
#         [  0,  89,   0],
#         [  0,  98,   0],
#         [  0, 106,   0]],
#
#        [[  0,  52,   0],
#         [  0,  52,   0],
#         [  0,  52,   0],
#         ...,
#         [  0,  91,   0],
#         [  0,  98,   0],
#         [  0, 110,   0]],
#
#        [[  0,  51,   0],
#         [  0,  51,   0],
#         [  0,  52,   0],
#         ...,
#         [  0,  92,   0],
#         [  0,  99,   0],
#         [  0, 113,   0]]], dtype=uint8)

# %%
blue_channel=image_array_colored.copy()
blue_channel[:,:,0]=0
blue_channel[:,:,1]=0
print(blue_channel)
display(blue_channel)
# Out:
# [[[  0   0  85]
#   [  0   0  85]
#   [  0   0  85]
#   ...
#   [  0   0 168]
#   [  0   0 171]
#   [  0   0 170]]
#
#  [[  0   0  85]
#   [  0   0  85]
#   [  0   0  86]
#   ...
#   [  0   0 177]
#   [  0   0 178]
#   [  0   0 177]]
#
#  [[  0   0  85]
#   [  0   0  85]
#   [  0   0  86]
#   ...
#   [  0   0 177]
#   [  0   0 178]
#   [  0   0 180]]
#
#  ...
#
#  [[  0   0  34]
#   [  0   0  34]
#   [  0   0  34]
#   ...
#   [  0   0  73]
#   [  0   0  84]
#   [  0   0  92]]
#
#  [[  0   0  34]
#   [  0   0  34]
#   [  0   0  34]
#   ...
#   [  0   0  75]
#   [  0   0  84]
#   [  0   0  96]]
#
#  [[  0   0  33]
#   [  0   0  33]
#   [  0   0  34]
#   ...
#   [  0   0  76]
#   [  0   0  85]
#   [  0   0  99]]]
# array([[[  0,   0,  85],
#         [  0,   0,  85],
#         [  0,   0,  85],
#         ...,
#         [  0,   0, 168],
#         [  0,   0, 171],
#         [  0,   0, 170]],
#
#        [[  0,   0,  85],
#         [  0,   0,  85],
#         [  0,   0,  86],
#         ...,
#         [  0,   0, 177],
#         [  0,   0, 178],
#         [  0,   0, 177]],
#
#        [[  0,   0,  85],
#         [  0,   0,  85],
#         [  0,   0,  86],
#         ...,
#         [  0,   0, 177],
#         [  0,   0, 178],
#         [  0,   0, 180]],
#
#        ...,
#
#        [[  0,   0,  34],
#         [  0,   0,  34],
#         [  0,   0,  34],
#         ...,
#         [  0,   0,  73],
#         [  0,   0,  84],
#         [  0,   0,  92]],
#
#        [[  0,   0,  34],
#         [  0,   0,  34],
#         [  0,   0,  34],
#         ...,
#         [  0,   0,  75],
#         [  0,   0,  84],
#         [  0,   0,  96]],
#
#        [[  0,   0,  33],
#         [  0,   0,  33],
#         [  0,   0,  34],
#         ...,
#         [  0,   0,  76],
#         [  0,   0,  85],
#         [  0,   0,  99]]], dtype=uint8)

# %% [markdown]
# Extracting Sub image from

# %%
row_100 = image_array_colored[100,:,:]
print(row_100)
display(Image.fromarray(row_100))
# Out:
# [[148 133  90]
#  [148 133  90]
#  [148 133  90]
#  ...
#  [254 254 254]
#  [254 254 254]
#  [254 254 254]]
# <PIL.Image.Image image mode=L size=3x736>

# %%
col_50=image_array_colored[:,50,:]
print(col_50)
display(Image.fromarray(col_50))
# Out:
# [[146 131  88]
#  [146 131  88]
#  [146 131  88]
#  ...
#  [112  92  65]
#  [115  96  66]
#  [117  98  66]]
# <PIL.Image.Image image mode=L size=3x920>

# %%
pixel =image_array_colored[10,20,:]
print(pixel)
# Out:
# [146 131  88]

# %% [markdown]
# Extracting sub images(cropping) using PIL

# %%
left=100
upper=50
right=200
lower=150
cropped_image = image_colored.crop((left,upper,right,lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# Saving numpy array into image

# %%
image_array = np.zeros((100,100,3), dtype=np.uint8)
image_from_array = Image.fromarray(image_array)
image_from_array.show()
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_array = np.ones((100,100,3), dtype=np.uint8)
image_from_array = Image.fromarray(image_array)
image_from_array.show()
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_from_array.save("output_image.jpg")

# %% [markdown]
# PCA
